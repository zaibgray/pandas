# %% [markdown]
# # [Zaib's AI Notebook](https://github.com/zaibgray/pandas) | Pandas
#
# What is Pandas
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# [About Pandas](https://pandas.pydata.org/about/index.html)

# %% [markdown]
# ## The Big Picture
# Think of Pandas like Microsoft Excel inside Python:
# - DataFrame = The entire Excel Sheet.
# - Series = A single column in that sheet.
# - Index = The row numbers on the far left.

# %% [markdown]
# ### 1. Series (1D Column)
# A Series is just a single column of data.
# - It can hold any data type (numbers, strings, booleans).
# - Every item in a Series must be the same type.
#
# ### 2. DataFrame (2D Table)
# A DataFrame is the main table structure.
# - It is made by gluing multiple Series together side-by-side.
# - Different columns can have different data types (e.g., text in one column, numbers in another).
#
# ### 3. Index (The Labels)
# The Index is the list of row labels.
# - By default, Pandas automatically numbers rows starting at 0 (0, 1, 2...).
# - You can change the index to use words or dates instead of numbers if you want.
#
#
# **Extracting:**
# If you pull a single column out of a DataFrame, it automatically becomes a Series.

# %% [markdown]
# ## Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pandas Series
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Series from lists

# %%
# strings

names = ["Alice", "Bob", "Charlie", "Diana"]
strings_series = pd.Series(names)
print(strings_series, type(strings_series))
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      Diana
# dtype: str <class 'pandas.Series'>

# %%
# integers

numbers = [10, -5, 42, 0, 7]
numbers_series = pd.Series(numbers)
print(numbers_series, type(numbers_series))
# Out:
# 0    10
# 1    -5
# 2    42
# 3     0
# 4     7
# dtype: int64 <class 'pandas.Series'>

# %% [markdown]
# ### Custom Indexing in Series

# %%
# custome index

name = ["Bob", "Lucky", "Ana"]
id = [1, 4, 7]
name_series = pd.Series(name, index=id)
print(name_series, type(name_series))
# Out:
# 1      Bob
# 4    Lucky
# 7      Ana
# dtype: str <class 'pandas.Series'>

# %% [markdown]
# ### Naming to column
# In a Pandas Series, the name attribute acts as the column header.

# %%
# setting a name

list_of_food = ["Apple", "Rice", "Bread", "Chicken", "BBQ", "Fish"]
list_index = [1, 3, 6, 7, 2, 4]
list_name = "MyFood"

food_series = pd.Series(list_of_food, index=list_index, name=list_name)
print(food_series, type(food_series))                                           #dtype tells about column data type
# Out:
# 1      Apple
# 3       Rice
# 6      Bread
# 7    Chicken
# 2        BBQ
# 4       Fish
# Name: MyFood, dtype: str <class 'pandas.Series'>

# %% [markdown]
# ### Series from Dictionary
#
# When you pass a dictionary to a pd.Series():
# - The dictionary Keys become the Index (row labels).
# - The dictionary Values become the actual Data.
# - Note: You still use the name= parameter separately to give the column a header.

# %%
students = {
    101 : "Bob",
    102 : "Alice",
    103 : "Lucy",
    104 : "Ana"
}

dictionary_series = pd.Series(students, name="students_data")
print(dictionary_series)
print(type(dictionary_series))
# Out:
# 101      Bob
# 102    Alice
# 103     Lucy
# 104      Ana
# Name: students_data, dtype: str
# <class 'pandas.Series'>

# %% [markdown]
# ### Pandas Series: Attributes & Use Cases
#
# | Attribute       | Use Case                              |
# | --------------- | ------------------------------------- |
# | `.index`        | Get the index of the Series           |
# | `.array`        | Get the underlying array              |
# | `.values`       | Get the values as a NumPy array       |
# | `.dtype`        | Check the data type                   |
# | `.dtypes`       | Check the data type                   |
# | `.shape`        | Get the size of the Series            |
# | `.ndim`         | Check the number of dimensions        |
# | `.size`         | Get the number of elements            |
# | `.nbytes`       | Check how much memory the values use  |
# | `.name`         | Get or change the Series name         |
# | `.empty`        | Check if the Series is empty          |
# | `.T`            | Transpose the Series                  |
# | `.axes`         | Get the axes of the Series            |
#
# ### Most Used in Daily AI/ML Work
#
# ```python
# s.index
# s.values
# s.dtype
# s.shape
# s.size
# s.name
# s.empty
# ```
#
#
# - **Pandas Series (1D):** Returns a tuple with a single number representing the rows: **(rows,)**.
# - **Pandas DataFrame (2D):** Returns a tuple representing rows and columns: **(rows, columns).**

# %%
my_list = [10, 20, 30, 40, 50, 60]
s = pd.Series(my_list, name="my_list")

# %%
# index
s.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# value
s.values
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
# data type
s.dtype
# Out:
# dtype('int64')

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
# shape (rows, columns)
s.shape
# Out:
# (6,)

# %%
# number of dimensions
s.ndim
# Out:
# 1

# %%
# size (rows * columns)
s.size
# Out:
# 6

# %%
s.nbytes
# Out:
# 48

# %%
# name gives the column header name
s.name
# Out:
# 'my_list'

# %%
# empty check if series is empty or not
s.empty
# Out:
# False

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: my_list, dtype: int64

# %%
# T -> mean traspose of matrix
# T works on 2D
s.T
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# Name: my_list, dtype: int64

# %%
s.axes
# Out:
# [RangeIndex(start=0, stop=6, step=1)]

# %%
s.is_unique
# Out:
# True

# %% [markdown]
# ### Series using read_csv

# %%
ds = pd.read_csv("series_data.csv").squeeze("columns")
print(ds)
# Out:
# 0      12
# 1      45
# 2      67
# 3      23
# 4      89
#        ..
# 215    45
# 216    81
# 217    26
# 218    69
# 219    37
# Name: 0, Length: 220, dtype: int64

# %%
print(ds.index)
print(ds.values)
print(ds.ndim)
print(ds.dtype)
print(ds.shape)
# Out:
# RangeIndex(start=0, stop=220, step=1)
# [12 45 67 23 89 34 56 78 91 10 43 65 27 84 39 72 18 55 93 31 76 24 68 15
#  87 42 59 33 71 96 21 64 38 82 49 77 14 53 88 29 61 35 73 19 94 46 58 26
#  81 37 69 11 52 85 32 74 17 63 90 28 47 79 13 66 41 95 22 57 83 36 70 16
#  54 92 25 62 48 86 30 75 20 44 97 51 80  9 60 40 89 34 78 23 67 12 56 91
#  43 35 72 18 84 29 63 47 76 15 88 52 31 69 24 93 38 57 81 14 65 42 79 26
#  95 33 61 19 87 45 73 10 58 82 36 94 21 64 49 77 13 53 90 28 71 40 86 17
#  55 92 30 68 44 75 22 59 83 16 96 34 62 48 85 27 70 11 54 89 39 78 25 66
#  43 91 18 74 32 63 47 80 14 57 95 36 69 20 88 41 76 29 52 84 13 61 93 35
#  67 24 79 46 90 31 56 72 15 82 38 64 27 71 49 86 19 58 94 33 75 12 63 45
#  81 26 69 37]
# 1
# int64
# (220,)

# %% [markdown]
# ### Pandas Series Methods
#
# #### 1. 📊 Information & Statistics
#
# | Method        | Simple Use Case                        |
# | ------------- | -------------------------------------- |
# | `.info()`     | Get basic information about the Series |
# | `.describe()` | Get a statistical summary              |
# | `.count()`    | Count non-missing values               |
# | `.sum()`      | Add all values                         |
# | `.mean()`     | Find the average                       |
# | `.median()`   | Find the middle value                  |
# | `.mode()`     | Find the most common value             |
# | `.min()`      | Find the smallest value                |
# | `.max()`      | Find the largest value                 |
# | `.std()`      | Measure how spread out the values are  |
# | `.var()`      | Measure the variance                   |
# | `.quantile()` | Find a percentile                      |
# | `.skew()`     | Check the skewness                     |
# | `.kurt()`     | Check the kurtosis                     |
# | `.abs()`      | Get the absolute values                |
# | `.round()`    | Round the values                       |
#
# ---
#
# #### 2. 🔍 Unique & Duplicate Values
#
# | Method               | Simple Use Case                    |
# | -------------------- | ---------------------------------- |
# | `.unique()`          | Get all unique values              |
# | `.nunique()`         | Count unique values                |
# | `.value_counts()`    | Count how often each value appears |
# | `.duplicated()`      | Find duplicate values              |
# | `.drop_duplicates()` | Remove duplicate values            |
# | `.is_unique`         | Check if all values are unique     |
#
# ---
#
# #### 3. ❌ Missing Values
#
# | Method           | Simple Use Case                              |
# | ---------------- | -------------------------------------------- |
# | `.isna()`        | Find missing values                          |
# | `.isnull()`      | Find missing values                          |
# | `.notna()`       | Find values that are not missing             |
# | `.dropna()`      | Remove missing values                        |
# | `.fillna()`      | Fill missing values                          |
# | `.interpolate()` | Fill missing values using interpolation      |
# | `.ffill()`       | Fill missing values using the previous value |
# | `.bfill()`       | Fill missing values using the next value     |
#
# ---
#
# #### 4. 🔄 Sorting & Index
#
# | Method           | Simple Use Case            |
# | ---------------- | -------------------------- |
# | `.sort_values()` | Sort values                |
# | `.sort_index()`  | Sort by index              |
# | `.reset_index()` | Reset the index            |
# | `.reindex()`     | Change the index           |
# | `.rename()`      | Rename the Series or index |
# | `.set_axis()`    | Set new index labels       |
#
# ---
#
# #### 5. ✏️ Changing Values & Data Type
#
# | Method              | Simple Use Case                    |
# | ------------------- | ---------------------------------- |
# | `.astype()`         | Change the data type               |
# | `.replace()`        | Replace specific values            |
# | `.convert_dtypes()` | Convert to suitable data types     |
# | `.copy()`           | Make a separate copy of the Series |
#
# ---
#
# #### 6. ⚙️ Apply & Transform
#
# | Method         | Simple Use Case                      |
# | -------------- | ------------------------------------ |
# | `.apply()`     | Apply a function to each value       |
# | `.map()`       | Map or transform values              |
# | `.transform()` | Transform the values                 |
# | `.where()`     | Keep values that meet a condition    |
# | `.mask()`      | Replace values that meet a condition |
# | `.clip()`      | Keep values within a range           |
#
# ---
#
# #### 7. 🔎 Filtering & Conditions
#
# | Method       | Simple Use Case                    |
# | ------------ | ---------------------------------- |
# | `.isin()`    | Check if values are in a list      |
# | `.between()` | Check if values are within a range |
# | `.filter()`  | Select values using their labels   |
#
# ---
#
# #### 8. 📈 Ranking & Selection
#
# | Method         | Simple Use Case                     |
# | -------------- | ----------------------------------- |
# | `.rank()`      | Give ranks to values                |
# | `.nlargest()`  | Get the largest values              |
# | `.nsmallest()` | Get the smallest values             |
# | `.idxmax()`    | Get the index of the largest value  |
# | `.idxmin()`    | Get the index of the smallest value |
# | `.sample()`    | Get random values                   |
#
# ---
#
# #### 9. 🔢 Cumulative & Difference
#
# | Method          | Simple Use Case                    |
# | --------------- | ---------------------------------- |
# | `.cumsum()`     | Get the cumulative sum             |
# | `.cummax()`     | Get the cumulative maximum         |
# | `.cummin()`     | Get the cumulative minimum         |
# | `.cumprod()`    | Get the cumulative product         |
# | `.diff()`       | Find the difference between values |
# | `.pct_change()` | Find the percentage change         |
# | `.shift()`      | Move values up or down             |
#
# ---
#
# #### 10. 🔄 Conversion
#
# | Method        | Simple Use Case                     |
# | ------------- | ----------------------------------- |
# | `.to_list()`  | Convert the Series to a Python list |
# | `.to_numpy()` | Convert the Series to a NumPy array |
# | `.to_frame()` | Convert the Series to a DataFrame   |
# | `.to_dict()`  | Convert the Series to a dictionary  |
# | `.to_csv()`   | Save the Series as a CSV file       |
#
# ---
#
# #### 11. 🧮 Other Useful Methods
#
# | Method         | Simple Use Case                            |
# | -------------- | ------------------------------------------ |
# | `.factorize()` | Convert unique values into numbers         |
# | `.explode()`   | Expand list-like values into separate rows |
# | `.item()`      | Get a single value from the Series         |
# | `.prod()`      | Multiply all values                        |
# | `.corr()`      | Find correlation with another Series       |
# | `.cov()`       | Find covariance with another Series        |
#
# ---
#
# ### ⭐ Most Important for AI/ML
#
# | Category            | Methods                                                       |
# | ------------------- | ------------------------------------------------------------- |
# | **View Data**       | `head()`, `tail()`                                            |
# | **Statistics**      | `describe()`, `mean()`, `median()`, `min()`, `max()`, `std()` |
# | **Missing Data**    | `isna()`, `fillna()`, `dropna()`, `interpolate()`             |
# | **Unique Data**     | `unique()`, `nunique()`, `value_counts()`                     |
# | **Sorting**         | `sort_values()`, `sort_index()`                               |
# | **Data Type**       | `astype()`, `convert_dtypes()`                                |
# | **Transformation**  | `apply()`, `map()`, `transform()`                             |
# | **Filtering**       | `isin()`, `between()`, `where()`, `mask()`                    |
# | **Selection**       | `nlargest()`, `nsmallest()`, `idxmax()`, `idxmin()`           |
# | **Ranking**         | `rank()`                                                      |
# | **Data Changes**    | `replace()`, `clip()`                                         |
# | **Cumulative Data** | `cumsum()`, `cummax()`, `cummin()`                            |
# | **Time/Change**     | `shift()`, `diff()`, `pct_change()`                           |
# | **Conversion**      | `to_numpy()`, `to_list()`, `to_frame()`                       |
